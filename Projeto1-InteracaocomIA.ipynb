# %% [markdown]
# Instalando o SDK do Google

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# Importando a biblioteca e criando um apelido (alias)

# %%
import google.generativeai as genai

# %% [markdown]
# Colocando a chave da API

# %%
GOOGLE_API_KEY='AIzaSyCN86v-UcvEXON71_CGVQq76hkSJHGCZ5Q'

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Inicializando o Modelo Generativo

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
       print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# Configurando parâmetros

# %%
primeiraconfiguracao = {
    'candidate_count':1,
    'temperature':0.5,
  }

# %% [markdown]
# Configurações de Segurança

# %%
segundaconfiguracao = {
    'harassment':'block_none',
    'hate':'block_none',
    'sexual':'block_none',
    'dangerous':'block_none',
}

# %% [markdown]
# Interagindo com o Modelo

# %%
#response =model.generate_content("Estou estudando IA, o que aconselha?")
model=genai.GenerativeModel(model_name='gemini-1.0-pro',
                            generation_config=primeiraconfiguracao,
                            safety_settings=segundaconfiguracao)

# %%
response = model.generate_content("Vamos aprender conteúdo sobre IA. Me dê sugestões")
print(response.text)
# Out:
# **Conceitos Fundamentais**
#
# * O que é Inteligência Artificial (IA)?
# * Tipos de IA: IA fraca, IA forte, IA geral
# * Aprendizado de Máquina (ML): Aprendizado supervisionado, não supervisionado e por reforço
# * Aprendizado Profundo (DL): Redes neurais, redes convolucionais e redes recorrentes
# * Processamento de Linguagem Natural (PNL): Reconhecimento de fala, geração de linguagem e tradução automática
#
# **Aplicações da IA**
#
# * Automação de processos
# * Análise preditiva e tomada de decisão
# * Reconhecimento de imagem e vídeo
# * Veículos autônomos
# * Assistentes virtuais e chatbots
# * Cuidados de saúde e diagnósticos médicos
# * Finanças e previsão de mercado
#
# **Ética e Implicações Sociais da IA**
#
# * Viés algorítmico e discriminação
# * Desemprego e deslocamento de empregos
# * Privacidade e vigilância
# * Responsabilidade e regulamentação
# * Implicações para a sociedade e o futuro do trabalho
#
# **Recursos de Aprendizagem**
#
# * **Cursos online:** Coursera, edX, Udemy
# * **Livros:** "Inteligência Artificial: Uma Abordagem Moderna" (Stuart Russell e Peter Norvig), "Aprendizado Profundo" (Ian Goodfellow, Yoshua Bengio e Aaron Courville)
# * **Artigos de pesquisa:** arXiv, IEEE Xplore
# * **Conferências e workshops:** NeurIPS, ICML, CVPR
# * **Comunidades online:** Reddit (r/MachineLearning, r/DeepLearning), Stack Overflow
#
# **Tendências e Avanços**
#
# * IA generativa (GPT-3, Dall-E 2)
# * Aprendizado de reforço profundo
# * IA explicável e confiável
# * IA quântica
# * IA em nuvem e borda

# %%
chat = model.start_chat(history=[])

# %%
prompt=input('Pesquise Algo: ')

while prompt != 'fim':
  response = chat.send_message(prompt)
  print('Resposta :', response.text, '\n')
  prompt=input('Pesquise Algo: ')
# Out:
# Pesquise Algo: fim

# %%
print(chat)
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.0-pro',
#         generation_config={'candidate_count': 1, 'temperature': 0.5},
#         safety_settings={<HarmCategory.HARM_CATEGORY_HARASSMENT: 7>: <HarmBlockThreshold.BLOCK_NONE: 4>, <HarmCategory.HARM_CATEGORY_HATE_SPEECH: 8>: <HarmBlockThreshold.BLOCK_NONE: 4>, <HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: 9>: <HarmBlockThreshold.BLOCK_NONE: 4>, <HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: 10>: <HarmBlockThreshold.BLOCK_NONE: 4>},
#         tools=None,
#         system_instruction=None,
#     ),
#     history=[]
# )
