# %% [markdown]
# Instalando o SDK do Google

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# Importando a biblioteca e criando um apelido

# %%
import google.generativeai as genai

# %% [markdown]
# Colocando a chave da API

# %%
GOOGLE_API_KEY='AIzaSyCN86v-UcvEXON71_CGVQq76hkSJHGCZ5Q'

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Inicializando o Modelo Generativo

# %%
model=genai.GenerativeModel('gemini-pro')

# %% [markdown]
# Interagindo com o modelo

# %%
response =model.generate_content("Estou estudando IA, o que aconselha?")

# %%
print(response.text)
# Out:
# **Dicas para Estudar Inteligência Artificial (IA)**
#
# **1. Fundamentos Sólidos:**
#
# * Comece com matemática (álgebra linear, cálculo, estatística) e programação (Python, Java).
# * Compreenda os princípios básicos da IA, como aprendizado de máquina, aprendizado profundo e processamento de linguagem natural.
#
# **2. Escolher um Caminho:**
#
# * Decida qual área de IA você deseja se especializar (aprendizado automático, visão computacional, processamento de linguagem natural).
# * Concentre-se em desenvolver habilidades e conhecimento específicos nessa área.
#
# **3. Recursos Online:**
#
# * Aproveite cursos online de plataformas como Coursera, edX e Udacity.
# * Participe de fóruns e comunidades online para discussões e networking.
# * Leia artigos de pesquisa, blogs e livros para se manter atualizado com as tendências da IA.
#
# **4. Projetos Práticos:**
#
# * Construa projetos práticos de IA para aplicar seus conhecimentos.
# ...
