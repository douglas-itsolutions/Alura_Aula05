# %%
import requests
url='https://raw.githubusercontent.com/guilhermeonrails/api-imersao-ia/main/words.json'
resposta = requests.get(url)
data = resposta.json()
len(data)
type(data)
# Out:
# list

# %%
import random
valor_secreto = random.choice(data)
palavra_secreta=valor_secreto['palavra']
dica = valor_secreto['dica']
#print(f'A palavra secreta tem {len(palavra_secreta)} letras -> {dica}')
#print(dica)
chute = input(f'A palavra secreta tem {len(palavra_secreta)} letras -> {dica}')
if chute == palavra_secreta:
  print('acertou')
else:
    print(f'errou {palavra_secreta}')
# Out:
# A palavra secreta tem 6 letras -> desenvolver aplicativos android modernos e seguros.kotlin
# acertou
