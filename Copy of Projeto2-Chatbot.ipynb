# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
GOOGLE_API_KEY='AIzaSyCN86v-UcvEXON71_CGVQq76hkSJHGCZ5Q'

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
       print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
primeiraconfiguracao = {
    'candidate_count':1,
    'temperature':0.5,
  }

# %%
segundaconfiguracao = {
    'harassment':'block_none',
    'hate':'block_none',
    'sexual':'block_none',
    'dangerous':'block_none',
}

# %%
model=genai.GenerativeModel(model_name='gemini-1.0-pro',
                            generation_config=primeiraconfiguracao,
                            safety_settings=segundaconfiguracao)

# %%
response = model.generate_content("Vamos aprender conteúdo sobre IA. Me dê sugestões")
print(response.text)
# Out:
# **Conceitos Fundamentais:**
#
# * Definição e história da Inteligência Artificial (IA)
# * Tipos de IA: Máquina de Aprendizado, Aprendizado Profundo, Processamento de Linguagem Natural
# * Algoritmos e técnicas de IA
# * Aplicações da IA em vários setores
#
# **Aprendizado de Máquina (ML):**
#
# * Tipos de ML: Supervisionado, Não Supervisionado, Reforço
# * Algoritmos de ML: Regressão, Classificação, Agrupamento
# * Treinamento e avaliação de modelos de ML
# * Aplicações de ML: Previsão, Detecção de Fraude, Recomendações
#
# **Aprendizado Profundo (DL):**
#
# * Redes Neurais: Arquiteturas, Treinamento e Otimização
# * Convolucional Neural Networks (CNNs)
# * Redes Neurais Recorrentes (RNNs)
# * Aplicações de DL: Visão Computacional, Processamento de Linguagem Natural
#
# **Processamento de Linguagem Natural (PNL):**
#
# * Técnicas de PNL: Tokenização, Stemming, Lematização
# * Modelos de Linguagem: Bag-of-Words, TF-IDF, Word2Vec
# * Classificação de Texto, Geração de Texto e Tradução Automática
# * Aplicações de PNL: Chatbots, Análise de Sentimento, Resumo de Texto
#
# **Ética e Implicações Sociais da IA:**
#
# * Viés e Discriminação na IA
# * Privacidade e Segurança
# * Impacto da IA no Emprego e na Sociedade
# * Diretrizes Éticas para o Desenvolvimento e Uso da IA
#
# **Recursos Adicionais:**
#
# * **Cursos Online:** Coursera, edX, Udacity
# * **Livros:** "Inteligência Artificial: Uma Abordagem Moderna" por Stuart Russell e Peter Norvig, "Aprendizado de Máquina para Iniciantes" por Andreas C. Müller e Sarah Guido
# * **Artigos de Pesquisa:** ArXiv, IEEE Xplore, ACM Digital Library
# * **Conferências e Eventos:** NeurIPS, ICML, CVPR
# * **Comunidades Online:** Stack Overflow, Reddit, GitHub
