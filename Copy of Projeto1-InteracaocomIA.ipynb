# %% [markdown]
# Instalando o SDK do Google

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# Importando a biblioteca e criando um apelido (alias)

# %%
import google.generativeai as genai

# %% [markdown]
# Colocando a chave da API

# %%
GOOGLE_API_KEY='AIzaSyCN86v-UcvEXON71_CGVQq76hkSJHGCZ5Q'

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Inicializando o Modelo Generativo

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
       print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# Configurando parâmetros

# %%
primeiraconfiguracao = {
    'candidate_count':1,
    'temperature':0.5,
  }

# %% [markdown]
# Configurações de Segurança

# %%
segundaconfiguracao = {
    'harassment':'block_none',
    'hate':'block_none',
    'sexual':'block_none',
    'dangerous':'block_none',
}

# %% [markdown]
# Interagindo com o Modelo

# %%
#response =model.generate_content("Estou estudando IA, o que aconselha?")
model=genai.GenerativeModel(model_name='gemini-1.0-pro',
                            generation_config=primeiraconfiguracao,
                            safety_settings=segundaconfiguracao)

# %%
response = model.generate_content("Vamos aprender conteúdo sobre IA. Me dê sugestões")
print(response.text)
# Out:
# **Introdução à Inteligência Artificial (IA)**
#
# * O que é IA?
# * Tipos de IA: aprendizado de máquina, aprendizado profundo, processamento de linguagem natural
# * Aplicações da IA em diferentes setores
#
# **Aprendizado de Máquina (ML)**
#
# * Conceitos básicos de ML: supervisão, não supervisão, reforço
# * Algoritmos de ML: regressão linear, árvores de decisão, redes neurais
# * Avaliação de modelos de ML: métricas, validação cruzada
#
# **Aprendizado Profundo (DL)**
#
# * Introdução ao DL: redes neurais convolucionais (CNNs), redes neurais recorrentes (RNNs)
# * Arquiteturas de DL: ResNet, Inception, Transformer
# * Aplicações de DL: reconhecimento de imagem, processamento de linguagem natural
#
# **Processamento de Linguagem Natural (PNL)**
#
# * Conceitos básicos de PNL: tokenização, análise sintática, semântica
# * Modelos de PNL: modelos de linguagem, modelos de tradução
# * Aplicações de PNL: chatbots, resumos de texto, tradução de idiomas
#
# **Ética e Implicações Sociais da IA**
#
# * Viés e discriminação em sistemas de IA
# * Privacidade e segurança na era da IA
# * Implicações econômicas e sociais da IA
#
# **Recursos de Aprendizado**
#
# * **Cursos online:** Coursera, edX, Udemy
# * **Livros:** "Inteligência Artificial: Um Guia Moderno" por Stuart Russell e Peter Norvig, "Aprendizado de Máquina" por Ethem Alpaydin
# * **Artigos de pesquisa:** IEEE Transactions on Artificial Intelligence, Journal of Machine Learning Research
# * **Comunidades online:** Stack Overflow, Reddit /r/MachineLearning
